# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 603

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Create data frame to store data for sample cities
citydata_df = pd.DataFrame({"City": cities,
                           "Cloudiness": "",
                           "Country": "",
                           "Date": "",
                           "Humidity": "",
                           "Lat": "",
                           "Lng": "",
                           "Max Temp": "",
                           "Wind Speed": ""})

citydata_df.head()
# Out:
#            City Cloudiness Country Date Humidity Lat Lng Max Temp Wind Speed
# 0       labutta
# 1  norman wells
# 2         enshi
# 3        polson
# 4       mataura

# %%
# Set base url to retrieve data 
base_url = "http://api.openweathermap.org/data/2.5/weather?"
appid = api_key
units = "imperial"

# For description in print log results 
record = 0
set = 1

print("Beginning Data Retrieval")
print("----------------------------------")

# Create loop in data frame to store data that is retrieved from url
for index, row in citydata_df.iterrows():
        
    q = row["City"]
    
    # Exception handling
    try:
        
        query_url = base_url + "units=" + units + "&appid=" + appid + "&q=" + q
        response = requests.get(query_url).json()
    
        print(f"processing record {record} of set {set} | {q}")
    
        citydata_df.loc[index, "Cloudiness"] = response["clouds"]["all"]
        citydata_df.loc[index, "Country"] = response["sys"]["country"]
        citydata_df.loc[index, "Date"] = response["dt"]
        citydata_df.loc[index, "Humidity"] = response["main"]["humidity"]
        citydata_df.loc[index, "Lat"] = response["coord"]["lat"]
        citydata_df.loc[index, "Lng"] = response["coord"]["lon"]
        citydata_df.loc[index, "Max Temp"] = response["main"]["temp_max"]
        citydata_df.loc[index, "Wind Speed"] = response["wind"]["speed"]
         
        record = record + 1
        if record >= 51:
            record = 0
            set = set + 1  
            
    except (KeyError, IndexError):
        print("City not found.  Skipping...")
        
print("------------------------------------")
print("Data Retrieval Complete")
print("------------------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------------
# processing record 0 of set 1 | labutta
# City not found.  Skipping...
# processing record 0 of set 1 | norman wells
# processing record 1 of set 1 | enshi
# processing record 2 of set 1 | polson
# processing record 3 of set 1 | mataura
# processing record 4 of set 1 | baie-comeau
# processing record 5 of set 1 | felidhoo
# City not found.  Skipping...
# processing record 5 of set 1 | vao
# processing record 6 of set 1 | albany
# processing record 7 of set 1 | san patricio
# processing record 8 of set 1 | new norfolk
# processing record 9 of set 1 | general roca
# processing record 10 of set 1 | tiksi
# processing record 11 of set 1 | shingu
# processing record 12 of set 1 | belushya guba
# City not found.  Skipping...
# processing record 12 of set 1 | nizhneyansk
# City not found.  Skipping...
# processing record 12 of set 1 | bologoye
# processing record 13 of set 1 | hermanus
# processing record 14 of set 1 | sulangan
# processing record 15 of set 1 | quang ngai
# processing record 16 of set 1 | virginia beach
# processing record 17 of set 1 | ostrovnoy
# processing record 18 of set 1 | saldanha
# processing record 19 of set 1 | jamestown
# processing record 20 of set 1 | miranorte
# City not found.  Skipping...
# processing record 20 of set 1 | srednekolymsk
# processing record 21 of set 1 | rong kwang
# processing record 22 of set 1 | vaini
# processing record 23 of set 1 | victoria
# processing record 24 of set 1 | honningsvag
# processing record 25 of set 1 | bethel
# processing record 26 of set 1 | butaritari
# processing record 27 of set 1 | aykhal
# processing record 28 of set 1 | khatanga
# processing record 29 of set 1 | ushuaia
# processing record 30 of set 1 | pangody
# processing record 31 of set 1 | tynda
# processing record 32 of set 1 | rikitea
# processing record 33 of set 1 | busselton
# processing record 32 of set 4 | hervey bay
# processing record 33 of set 4 | klaksvik
# processing record 34 of set 4 | kailua
# processing record 35 of set 4 | oriximina
# processing record 36 of set 4 | tunduru
# City not found.  Skipping...
# processing record 36 of set 4 | babushkin
# processing record 37 of set 4 | lavrentiya
# processing record 38 of set 4 | jutai
# processing record 39 of set 4 | shimanovsk
# processing record 40 of set 4 | oranjemund
# processing record 41 of set 4 | sept-iles
# processing record 42 of set 4 | vila velha
# processing record 43 of set 4 | akyab
# City not found.  Skipping...
# processing record 43 of set 4 | portland
# processing record 44 of set 4 | aklavik
# processing record 45 of set 4 | chimbote
# processing record 46 of set 4 | gurskoye
# City not found.  Skipping...
# processing record 46 of set 4 | napajedla
# processing record 47 of set 4 | clyde river
# processing record 48 of set 4 | imeni zhelyabova
# processing record 49 of set 4 | wahran
# City not found.  Skipping...
# processing record 49 of set 4 | soderhamn
# processing record 50 of set 4 | uklana mandi
# processing record 0 of set 5 | cabo san lucas
# processing record 1 of set 5 | viedma
# processing record 2 of set 5 | islahiye
# processing record 3 of set 5 | providencia
# processing record 4 of set 5 | labuhan
# processing record 5 of set 5 | amderma
# City not found.  Skipping...
# processing record 5 of set 5 | bouloupari
# processing record 6 of set 5 | miles city
# processing record 7 of set 5 | mrirt
# City not found.  Skipping...
# processing record 7 of set 5 | buchanan
# processing record 8 of set 5 | harnosand
# processing record 9 of set 5 | thompson
# processing record 10 of set 5 | riberalta
# processing record 11 of set 5 | rettikhovka
# processing record 12 of set 5 | marsaxlokk
# processing record 13 of set 5 | gulu
# processing record 14 of set 5 | gallup
# processing record 15 of set 5 | necochea
# processing record 16 of set 5 | borogontsy
# processing record 17 of set 5 | asau
# City not found.  Skipping...
# processing record 17 of set 5 | ulladulla
# processing record 18 of set 5 | kahramanmaras
# processing record 19 of set 5 | galesong
# processing record 20 of set 5 | glendive
# processing record 21 of set 5 | san policarpo
# processing record 22 of set 5 | matara
# processing record 23 of set 5 | ahipara
# processing record 24 of set 5 | tsihombe
# City not found.  Skipping...
# processing record 24 of set 5 | ancud
# processing record 25 of set 5 | oksfjord
# processing record 26 of set 5 | payo
# processing record 27 of set 5 | hamilton
# processing record 28 of set 5 | boende
# processing record 29 of set 5 | carutapera
# processing record 30 of set 5 | helsinki
# processing record 31 of set 5 | vardo
# processing record 32 of set 5 | hualmay
# processing record 33 of set 5 | vaitupu
# City not found.  Skipping...
# processing record 33 of set 5 | nikolsk
# processing record 34 of set 5 | benicarlo
# processing record 35 of set 5 | batetskiy
# processing record 36 of set 5 | mahina
# processing record 37 of set 5 | champerico
# processing record 38 of set 5 | sibolga
# processing record 39 of set 5 | crispiano
# processing record 40 of set 5 | magistralnyy
# processing record 41 of set 5 | rio gallegos
# processing record 42 of set 5 | louisbourg
# City not found.  Skipping...
# processing record 42 of set 5 | duluth
# processing record 43 of set 5 | wairoa
# processing record 44 of set 5 | nanortalik
# processing record 45 of set 5 | ilhabela
# processing record 46 of set 5 | shache
# processing record 47 of set 5 | saint-francois
# processing record 48 of set 5 | carupano
# processing record 49 of set 5 | krasnotorka
# processing record 50 of set 5 | borovskoy
# processing record 0 of set 6 | katsiveli
# City not found.  Skipping...
# processing record 0 of set 6 | grand river south east
# City not found.  Skipping...
# processing record 0 of set 6 | buraydah
# processing record 1 of set 6 | zaragoza
# processing record 2 of set 6 | rawson
# processing record 3 of set 6 | cockburn town
# processing record 4 of set 6 | souillac
# processing record 5 of set 6 | montepuez
# processing record 6 of set 6 | longyearbyen
# processing record 7 of set 6 | abu dhabi
# processing record 8 of set 6 | ballina
# processing record 9 of set 6 | bargal
# City not found.  Skipping...
# processing record 9 of set 6 | batagay
# processing record 10 of set 6 | katherine
# processing record 11 of set 6 | turbat
# processing record 12 of set 6 | chapais
# processing record 13 of set 6 | torbay
# processing record 14 of set 6 | alotau
# City not found.  Skipping...
# processing record 14 of set 6 | sur
# processing record 15 of set 6 | port elizabeth
# processing record 16 of set 6 | lolua
# City not found.  Skipping...
# processing record 16 of set 6 | tomatlan
# processing record 17 of set 6 | riyadh
# processing record 18 of set 6 | svetlyy
# City not found.  Skipping...
# processing record 18 of set 6 | wuwei
# processing record 19 of set 6 | panjwin
# City not found.  Skipping...
# processing record 19 of set 6 | molde
# processing record 20 of set 6 | nome
# processing record 21 of set 6 | kruisfontein
# processing record 22 of set 6 | vazante
# processing record 23 of set 6 | izumo
# processing record 24 of set 6 | jasper
# processing record 25 of set 6 | moffat
# processing record 26 of set 6 | russell
# processing record 27 of set 6 | brigantine
# processing record 28 of set 6 | najran
# processing record 29 of set 6 | pontes e lacerda
# processing record 30 of set 6 | businga
# processing record 31 of set 6 | ewo
# processing record 32 of set 6 | kaduqli
# processing record 33 of set 6 | cidreira
# processing record 34 of set 6 | bilma
# processing record 35 of set 6 | budogoshch
# processing record 36 of set 6 | kemijarvi
# City not found.  Skipping...
# processing record 36 of set 6 | stornoway
# City not found.  Skipping...
# processing record 36 of set 6 | plana nad luznici
# processing record 37 of set 6 | praia
# processing record 38 of set 6 | yulara
# processing record 39 of set 6 | erdenet
# processing record 40 of set 6 | bharatpur
# processing record 41 of set 6 | warqla
# City not found.  Skipping...
# processing record 41 of set 6 | tilichiki
# processing record 42 of set 6 | qingan
# City not found.  Skipping...
# processing record 42 of set 6 | saleaula
# City not found.  Skipping...
# processing record 42 of set 6 | narsaq
# processing record 43 of set 6 | aci castello
# processing record 44 of set 6 | malanje
# processing record 45 of set 6 | boueni
# processing record 46 of set 6 | fortuna
# processing record 47 of set 6 | mocuba
# processing record 48 of set 6 | guayama
# processing record 49 of set 6 | los llanos de aridane
# processing record 50 of set 6 | muros
# processing record 0 of set 7 | mamit
# processing record 1 of set 7 | hirara
# processing record 2 of set 7 | anito
# processing record 3 of set 7 | port blair
# processing record 4 of set 7 | leningradskiy
# processing record 5 of set 7 | acapulco
# processing record 6 of set 7 | verkhnevilyuysk
# processing record 7 of set 7 | chornyanka
# processing record 8 of set 7 | lorengau
# processing record 9 of set 7 | dali
# processing record 10 of set 7 | darhan
# processing record 11 of set 7 | broome
# processing record 12 of set 7 | tayzhina
# processing record 13 of set 7 | ngunguru
# processing record 14 of set 7 | lloydminster
# processing record 15 of set 7 | soe
# processing record 16 of set 7 | fort smith
# processing record 17 of set 7 | sokoto
# processing record 18 of set 7 | boyolangu
# processing record 19 of set 7 | villa union
# processing record 20 of set 7 | gornopravdinsk
# processing record 21 of set 7 | goycay
# City not found.  Skipping...
# processing record 21 of set 7 | palmer
# processing record 22 of set 7 | beringovskiy
# processing record 23 of set 7 | castrillon
# processing record 24 of set 7 | adilcevaz
# processing record 25 of set 7 | sorvag
# City not found.  Skipping...
# processing record 25 of set 7 | singapore
# processing record 26 of set 7 | flinders
# processing record 27 of set 7 | sola
# processing record 28 of set 7 | tachia
# City not found.  Skipping...
# processing record 28 of set 7 | ilo
# processing record 29 of set 7 | samusu
# City not found.  Skipping...
# processing record 29 of set 7 | tasiilaq
# processing record 30 of set 7 | berdigestyakh
# processing record 31 of set 7 | tabuk
# processing record 32 of set 7 | mago
# processing record 33 of set 7 | emerald
# processing record 34 of set 7 | airai
# processing record 35 of set 7 | nenjiang
# processing record 36 of set 7 | umea
# processing record 37 of set 7 | vokhtoga
# processing record 38 of set 7 | clarksburg
# processing record 39 of set 7 | cherskiy
# processing record 40 of set 7 | sentyabrskiy
# City not found.  Skipping...
# processing record 40 of set 7 | san miguel
# processing record 41 of set 7 | merauke
# processing record 42 of set 7 | boguchany
# processing record 43 of set 7 | boa vista
# processing record 44 of set 7 | camacari
# processing record 45 of set 7 | hami
# processing record 46 of set 7 | hillsborough
# processing record 47 of set 7 | tautira
# processing record 48 of set 7 | mongomo
# processing record 49 of set 7 | koumac
# processing record 50 of set 7 | mwaya
# City not found.  Skipping...
# processing record 50 of set 7 | isangel
# processing record 0 of set 8 | shitanjing
# processing record 1 of set 8 | masindi
# processing record 2 of set 8 | mys shmidta
# City not found.  Skipping...
# processing record 2 of set 8 | bouna
# processing record 3 of set 8 | murray
# processing record 4 of set 8 | sungaipenuh
# processing record 5 of set 8 | port-gentil
# processing record 6 of set 8 | killybegs
# processing record 7 of set 8 | erenhot
# processing record 8 of set 8 | trapani
# processing record 9 of set 8 | linxia
# processing record 10 of set 8 | mount gambier
# processing record 11 of set 8 | porkhov
# processing record 12 of set 8 | sakakah
# City not found.  Skipping...
# processing record 12 of set 8 | batagay-alyta
# processing record 13 of set 8 | bathsheba
# processing record 14 of set 8 | noumea
# processing record 15 of set 8 | meulaboh
# processing record 16 of set 8 | prudentopolis
# processing record 17 of set 8 | metehara
# City not found.  Skipping...
# processing record 17 of set 8 | aden
# processing record 18 of set 8 | umzimvubu
# City not found.  Skipping...
# processing record 18 of set 8 | nguiu
# City not found.  Skipping...
# processing record 18 of set 8 | tuggurt
# City not found.  Skipping...
# processing record 18 of set 8 | nador
# processing record 19 of set 8 | srivardhan
# processing record 20 of set 8 | ternate
# processing record 21 of set 8 | bambous virieux
# processing record 22 of set 8 | kamaishi
# processing record 23 of set 8 | belaya gora
# processing record 24 of set 8 | roald
# processing record 25 of set 8 | chemal
# processing record 26 of set 8 | gelendzhik
# processing record 27 of set 8 | tatishchevo
# processing record 28 of set 8 | rumonge
# processing record 29 of set 8 | bulungu
# processing record 30 of set 8 | atambua
# processing record 31 of set 8 | alofi
# processing record 32 of set 8 | vila franca do campo
# processing record 33 of set 8 | belle fourche
# processing record 34 of set 8 | bundaberg
# processing record 35 of set 8 | sinkat
# City not found.  Skipping...
# processing record 35 of set 8 | zhigansk
# processing record 36 of set 8 | burica
# City not found.  Skipping...
# processing record 36 of set 8 | pierre
# processing record 37 of set 8 | asyut
# processing record 38 of set 8 | mirganj
# processing record 39 of set 8 | churapcha
# processing record 40 of set 8 | maniitsoq
# processing record 41 of set 8 | halifax
# processing record 42 of set 8 | tarn taran
# processing record 43 of set 8 | yucca valley
# processing record 44 of set 8 | fonte boa
# processing record 45 of set 8 | svetlogorsk
# processing record 46 of set 8 | itarema
# processing record 47 of set 8 | poykovskiy
# processing record 48 of set 8 | volax
# processing record 49 of set 8 | port hedland
# processing record 50 of set 8 | ketchikan
# processing record 0 of set 9 | tual
# processing record 1 of set 9 | paciran
# processing record 2 of set 9 | petropavlovsk-kamchatskiy
# processing record 3 of set 9 | boromo
# processing record 4 of set 9 | ayorou
# processing record 5 of set 9 | dingle
# processing record 6 of set 9 | matina
# processing record 7 of set 9 | ishigaki
# processing record 8 of set 9 | uyovu
# processing record 9 of set 9 | havelock
# processing record 10 of set 9 | tura
# processing record 11 of set 9 | kuyanovo
# processing record 12 of set 9 | thohoyandou
# processing record 13 of set 9 | kahului
# processing record 14 of set 9 | deputatskiy
# processing record 15 of set 9 | nara
# processing record 16 of set 9 | paradwip
# City not found.  Skipping...
# processing record 16 of set 9 | manaia
# processing record 17 of set 9 | iquique
# processing record 18 of set 9 | berlevag
# processing record 19 of set 9 | sitka
# processing record 20 of set 9 | minab
# processing record 21 of set 9 | sao gabriel da cachoeira
# processing record 22 of set 9 | arinos
# processing record 23 of set 9 | mormugao
# City not found.  Skipping...
# processing record 23 of set 9 | monte alegre de minas
# processing record 24 of set 9 | alekseyevsk
# processing record 25 of set 9 | tiznit
# processing record 26 of set 9 | barbar
# City not found.  Skipping...
# processing record 26 of set 9 | belyy yar
# processing record 27 of set 9 | whittlesea
# processing record 28 of set 9 | margate
# processing record 29 of set 9 | kamenskoye
# City not found.  Skipping...
# processing record 29 of set 9 | fairbanks
# processing record 30 of set 9 | vorotynets
# processing record 31 of set 9 | saint-joseph
# processing record 32 of set 9 | north bend
# processing record 33 of set 9 | colares
# processing record 34 of set 9 | nuuk
# processing record 35 of set 9 | mithimna
# City not found.  Skipping...
# processing record 35 of set 9 | uvira
# processing record 36 of set 9 | petropavlovka
# processing record 37 of set 9 | port lincoln
# processing record 38 of set 9 | ulfborg
# processing record 39 of set 9 | kalush
# processing record 40 of set 9 | dabakala
# processing record 41 of set 9 | dicabisagan
# processing record 42 of set 9 | karratha
# processing record 43 of set 9 | bac can
# City not found.  Skipping...
# processing record 43 of set 9 | kousseri
# City not found.  Skipping...
# processing record 43 of set 9 | maunabo
# processing record 44 of set 9 | college
# processing record 45 of set 9 | pisco
# processing record 46 of set 9 | mattru
# processing record 47 of set 9 | san fernando
# processing record 48 of set 9 | carbondale
# processing record 49 of set 9 | hunza
# City not found.  Skipping...
# processing record 49 of set 9 | yei
# City not found.  Skipping...
# processing record 49 of set 9 | comodoro rivadavia
# processing record 50 of set 9 | kazalinsk
# City not found.  Skipping...
# processing record 50 of set 9 | babanusah
# City not found.  Skipping...
# processing record 50 of set 9 | glazov
# processing record 0 of set 10 | abhar
# processing record 1 of set 10 | vagur
# processing record 2 of set 10 | lisakovsk
# processing record 3 of set 10 | gorele
# processing record 4 of set 10 | kalakamati
# processing record 5 of set 10 | muroto
# processing record 6 of set 10 | lokachi
# processing record 7 of set 10 | ugoofaaru
# processing record 8 of set 10 | yerbogachen
# processing record 9 of set 10 | baruun-urt
# processing record 10 of set 10 | amapa
# processing record 11 of set 10 | salalah
# processing record 12 of set 10 | camopi
# processing record 13 of set 10 | normandin
# processing record 14 of set 10 | karpogory
# processing record 15 of set 10 | qunduz
# City not found.  Skipping...
# processing record 15 of set 10 | ambikapur
# processing record 16 of set 10 | phan rang
# City not found.  Skipping...
# processing record 16 of set 10 | tumannyy
# City not found.  Skipping...
# processing record 16 of set 10 | taitung
# processing record 17 of set 10 | abomey
# processing record 18 of set 10 | arlit
# processing record 19 of set 10 | podgornoye
# processing record 20 of set 10 | marcona
# City not found.  Skipping...
# processing record 20 of set 10 | puerto el triunfo
# processing record 21 of set 10 | kysyl-syr
# processing record 22 of set 10 | san juan
# processing record 23 of set 10 | smolenskoye
# processing record 24 of set 10 | iqaluit
# processing record 25 of set 10 | lushunkou
# City not found.  Skipping...
# processing record 25 of set 10 | chok chai
# processing record 26 of set 10 | gamba
# processing record 27 of set 10 | baoning
# processing record 28 of set 10 | kununurra

# %%
citydata_df

# %%
citydata_df.count()

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Export file into a csv 
citydata_df.to_csv("cities.csv", index=False)

# %%
citydata_df.dtypes

# %%
# Convert data into numerical float type for graphing
citydata_df["Cloudiness"] = pd.to_numeric(citydata_df["Cloudiness"])
citydata_df["Date"] = pd.to_numeric(citydata_df["Date"])
citydata_df["Humidity"] = pd.to_numeric(citydata_df["Humidity"])
citydata_df["Lat"] = pd.to_numeric(citydata_df["Lat"])
citydata_df["Lng"] = pd.to_numeric(citydata_df["Lng"])
citydata_df["Max Temp"] = pd.to_numeric(citydata_df["Max Temp"])
citydata_df["Wind Speed"] = pd.to_numeric(citydata_df["Wind Speed"])

# %%
citydata_df.dtypes

# %% [markdown]
# Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Set x-axis and y-axis for graph
x_axis = citydata_df["Lat"]
y_axis = citydata_df["Max Temp"]

# Scatter Plot
plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black", alpha=1.0)

# Labels for graph
plt.title("City Latitude vs. Max Temperature (12/01/19)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("latitude_temp.png")

plt.show

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
x_axis = citydata_df["Lat"]
y_axis = citydata_df["Humidity"]

plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black", alpha=1.0)

plt.title("City Latitude vs. Humidity (12/01/19)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("latitude_humidity.png")

plt.show

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
x_axis = citydata_df["Lat"]
y_axis = citydata_df["Max Temp"]

plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black", alpha=1.0)

plt.title("City Latitude vs. Cloudiness (12/01/19)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("latitude_cloudiness.png")

plt.show

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
x_axis = citydata_df["Lat"]
y_axis = citydata_df["Wind Speed"]

plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black", alpha=1.0)

plt.title("City Latitude vs. Wind Speed (12/01/19)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("latitude_windspeed.png")

plt.show
