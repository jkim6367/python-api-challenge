# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 601

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Create data frame to store data for sample cities
citydata_df = pd.DataFrame({"City": cities,
                           "Cloudiness": "",
                           "Country": "",
                           "Date": "",
                           "Humidity": "",
                           "Lat": "",
                           "Lng": "",
                           "Max Temp": "",
                           "Wind Speed": ""})

citydata_df.head()
# Out:
#             City Cloudiness Country Date Humidity Lat Lng Max Temp Wind Speed
# 0   sentyabrskiy
# 1       chabahar
# 2      dien bien
# 3    yellowknife
# 4  mar del plata

# %%
# Set base url to retrieve data 
base_url = "http://api.openweathermap.org/data/2.5/weather?"
appid = api_key
units = "imperial"

# For description in print log results 
record = 0
set = 1

print("Beginning Data Retrieval")
print("----------------------------------")

# Create loop in data frame to store data that is retrieved from url
for index, row in citydata_df.iterrows():
        
    q = row["City"]
    
    # Exception handling
    try:
        
        query_url = base_url + "units=" + units + "&appid=" + appid + "&q=" + q
        response = requests.get(query_url).json()
    
        print(f"processing record {record} of set {set} | {q}")
    
        citydata_df.loc[index, "Cloudiness"] = response["clouds"]["all"]
        citydata_df.loc[index, "Country"] = response["sys"]["country"]
        citydata_df.loc[index, "Date"] = response["dt"]
        citydata_df.loc[index, "Humidity"] = response["main"]["humidity"]
        citydata_df.loc[index, "Lat"] = response["coord"]["lat"]
        citydata_df.loc[index, "Lng"] = response["coord"]["lon"]
        citydata_df.loc[index, "Max Temp"] = response["main"]["temp_max"]
        citydata_df.loc[index, "Wind Speed"] = response["wind"]["speed"]
         
        record = record + 1
        if record >= 51:
            record = 0
            set = set + 1  
            
    except (KeyError, IndexError):
        print("City not found.  Skipping...")
        
print("------------------------------------")
print("Data Retrieval Complete")
print("------------------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------------
# processing record 0 of set 1 | sentyabrskiy
# City not found.  Skipping...
# processing record 0 of set 1 | chabahar
# processing record 1 of set 1 | dien bien
# City not found.  Skipping...
# processing record 1 of set 1 | yellowknife
# processing record 2 of set 1 | mar del plata
# processing record 3 of set 1 | olpad
# processing record 4 of set 1 | atuona
# processing record 5 of set 1 | cape town
# processing record 6 of set 1 | xinyu
# processing record 7 of set 1 | nenjiang
# processing record 8 of set 1 | puerto ayora
# processing record 9 of set 1 | katsuura
# processing record 10 of set 1 | wanning
# processing record 11 of set 1 | cockburn town
# processing record 12 of set 1 | bonthe
# processing record 13 of set 1 | lebu
# processing record 14 of set 1 | albany
# processing record 15 of set 1 | agliana
# processing record 16 of set 1 | mataura
# processing record 17 of set 1 | rikitea
# processing record 18 of set 1 | avarua
# processing record 19 of set 1 | ushuaia
# processing record 20 of set 1 | grand gaube
# processing record 21 of set 1 | jamestown
# processing record 22 of set 1 | taolanaro
# City not found.  Skipping...
# processing record 22 of set 1 | osa
# processing record 23 of set 1 | hobart
# processing record 24 of set 1 | bassar
# processing record 25 of set 1 | necochea
# processing record 26 of set 1 | thompson
# processing record 27 of set 1 | moroto
# processing record 28 of set 1 | saskylakh
# processing record 29 of set 1 | baherden
# processing record 30 of set 1 | belushya guba
# City not found.  Skipping...
# processing record 30 of set 1 | punta arenas
# processing record 31 of set 1 | hithadhoo
# processing record 32 of set 1 | chambas
# processing record 33 of set 1 | port elizabeth
# processing record 34 of set 1 | saint-philippe
# processing record 35 of set 1 | port alfred
# processing record 36 of set 1 | shenjiamen
# processing record 37 of set 1 | kruisfontein
# processing record 38 of set 1 | kattivakkam
# processing record 39 of set 1 | vaini
# processing record 40 of set 1 | busselton
# processing record 41 of set 1 | toliary
# City not found.  Skipping...
# processing record 41 of set 1 | castro
# processing record 42 of set 1 | deputatskiy
# processing record 43 of set 1 | shimoda
# processing record 44 of set 1 | siavonga
# processing record 45 of set 1 | aquiraz
# processing record 46 of set 1 | ancud
# processing record 47 of set 1 | kolpashevo
# processing record 48 of set 1 | rocha
# processing record 49 of set 1 | lagoa
# processing record 50 of set 1 | saldanha
# processing record 0 of set 2 | victoria
# processing record 1 of set 2 | hermanus
# processing record 2 of set 2 | arraial do cabo
# processing record 3 of set 2 | nouadhibou
# processing record 4 of set 2 | hit
# processing record 5 of set 2 | tasiilaq
# processing record 6 of set 2 | namibe
# processing record 7 of set 2 | dikson
# processing record 8 of set 2 | clyde river
# processing record 9 of set 2 | port hope
# processing record 10 of set 2 | luderitz
# processing record 11 of set 2 | lakhisarai
# processing record 12 of set 2 | butaritari
# processing record 13 of set 2 | yarada
# processing record 14 of set 2 | ossora
# processing record 15 of set 2 | longlac
# City not found.  Skipping...
# processing record 15 of set 2 | saint george
# processing record 16 of set 2 | sorgun
# processing record 17 of set 2 | baruun-urt
# processing record 18 of set 2 | waingapu
# processing record 19 of set 2 | den helder
# processing record 20 of set 2 | coquimbo
# processing record 21 of set 2 | carnarvon
# processing record 22 of set 2 | moussoro
# processing record 23 of set 2 | ostrovnoy
# processing record 24 of set 2 | illoqqortoormiut
# City not found.  Skipping...
# processing record 24 of set 2 | nikolskoye
# processing record 25 of set 2 | coihaique
# processing record 26 of set 2 | puerto escondido
# processing record 27 of set 2 | hamilton
# processing record 28 of set 2 | cidreira
# processing record 29 of set 2 | san andres
# processing record 30 of set 2 | attawapiskat
# City not found.  Skipping...
# processing record 30 of set 2 | haibowan
# City not found.  Skipping...
# processing record 30 of set 2 | saint-joseph
# processing record 31 of set 2 | dabakala
# processing record 32 of set 2 | goure
# processing record 33 of set 2 | high rock
# processing record 34 of set 2 | codrington
# processing record 35 of set 2 | bida
# processing record 36 of set 2 | mozarlandia
# processing record 37 of set 2 | meulaboh
# processing record 38 of set 2 | new norfolk
# processing record 39 of set 2 | walvis bay
# processing record 40 of set 2 | barrow
# processing record 41 of set 2 | san patricio
# processing record 42 of set 2 | talaya
# processing record 43 of set 2 | cherskiy
# processing record 44 of set 2 | bambous virieux
# processing record 45 of set 2 | east london
# processing record 46 of set 2 | tahara
# processing record 47 of set 2 | kodiak
# processing record 48 of set 2 | karratha
# processing record 49 of set 2 | tromso
# processing record 50 of set 2 | aberdeen
# processing record 0 of set 3 | ontario
# processing record 1 of set 3 | broome
# processing record 2 of set 3 | ulladulla
# processing record 3 of set 3 | kichmengskiy gorodok
# processing record 4 of set 3 | torbay
# processing record 5 of set 3 | tomatlan
# processing record 6 of set 3 | hunchun
# processing record 7 of set 3 | colac
# processing record 8 of set 3 | broken hill
# processing record 9 of set 3 | longyearbyen
# processing record 10 of set 3 | lokosovo
# processing record 11 of set 3 | gurupi
# processing record 12 of set 3 | attock
# processing record 13 of set 3 | kalmunai
# processing record 14 of set 3 | severo-kurilsk
# processing record 15 of set 3 | husavik
# processing record 16 of set 3 | georgetown
# processing record 17 of set 3 | westport
# processing record 18 of set 3 | faanui
# processing record 19 of set 3 | chuy
# processing record 20 of set 3 | bilma
# processing record 21 of set 3 | burgersdorp
# processing record 22 of set 3 | luanda
# processing record 23 of set 3 | tinskoy
# processing record 24 of set 3 | muros
# processing record 25 of set 3 | abu kamal
# processing record 26 of set 3 | los llanos de aridane
# processing record 27 of set 3 | rawson
# processing record 28 of set 3 | qaanaaq
# processing record 29 of set 3 | pochutla
# processing record 30 of set 3 | bluff
# processing record 31 of set 3 | yar-sale
# processing record 32 of set 3 | alofi
# processing record 33 of set 3 | guymon
# processing record 34 of set 3 | te anau
# processing record 35 of set 3 | altagracia de orituco
# processing record 36 of set 3 | dingle
# processing record 37 of set 3 | alta floresta
# processing record 38 of set 3 | jiazi
# processing record 39 of set 3 | chokurdakh
# processing record 40 of set 3 | souillac
# processing record 41 of set 3 | griffith
# processing record 42 of set 3 | klaksvik
# processing record 43 of set 3 | sorland
# processing record 44 of set 3 | limon
# processing record 45 of set 3 | roma
# processing record 46 of set 3 | thyolo
# processing record 47 of set 3 | natal
# processing record 48 of set 3 | hilo
# processing record 49 of set 3 | iqaluit
# processing record 50 of set 3 | olinda
# processing record 0 of set 4 | tiksi
# processing record 1 of set 4 | soyo
# processing record 2 of set 4 | bandarbeyla
# processing record 3 of set 4 | vysokogornyy
# processing record 4 of set 4 | yerbogachen
# processing record 5 of set 4 | ust-nera
# processing record 6 of set 4 | jiddah
# City not found.  Skipping...
# processing record 6 of set 4 | samusu
# City not found.  Skipping...
# processing record 6 of set 4 | tsihombe
# City not found.  Skipping...
# processing record 6 of set 4 | cabedelo
# processing record 7 of set 4 | pevek
# processing record 8 of set 4 | hami
# processing record 9 of set 4 | post falls
# processing record 10 of set 4 | nuuk
# processing record 11 of set 4 | fortuna
# processing record 12 of set 4 | talnakh
# processing record 13 of set 4 | plettenberg bay
# processing record 14 of set 4 | tura
# processing record 15 of set 4 | antofagasta
# processing record 16 of set 4 | cabo san lucas
# processing record 17 of set 4 | sale
# processing record 18 of set 4 | zhigansk
# processing record 19 of set 4 | vilhena
# processing record 20 of set 4 | leshukonskoye
# processing record 21 of set 4 | tabou
# processing record 22 of set 4 | schleswig
# processing record 23 of set 4 | khatanga
# processing record 24 of set 4 | kavaratti
# processing record 25 of set 4 | camanducaia
# processing record 26 of set 4 | tuktoyaktuk
# processing record 27 of set 4 | nyandoma
# processing record 28 of set 4 | celestun
# processing record 29 of set 4 | tual
# processing record 30 of set 4 | kaitangata
# processing record 31 of set 4 | provideniya
# processing record 32 of set 4 | khandbari
# processing record 33 of set 4 | murray bridge
# processing record 34 of set 4 | paamiut
# processing record 35 of set 4 | ponta do sol
# processing record 36 of set 4 | bakchar
# processing record 37 of set 4 | tongzhou
# processing record 38 of set 4 | cam pha
# City not found.  Skipping...
# processing record 38 of set 4 | sedan
# processing record 39 of set 4 | rabo de peixe
# processing record 40 of set 4 | bahraich
# processing record 41 of set 4 | acajutla
# processing record 42 of set 4 | buala
# processing record 43 of set 4 | dubenskiy
# City not found.  Skipping...
# processing record 43 of set 4 | novoorsk
# processing record 44 of set 4 | lorengau
# processing record 45 of set 4 | kieta
# processing record 46 of set 4 | pemberton
# processing record 47 of set 4 | ayan
# processing record 48 of set 4 | kailua
# processing record 49 of set 4 | la ronge
# processing record 50 of set 4 | belem de sao francisco
# processing record 0 of set 5 | tuatapere
# processing record 1 of set 5 | kazalinsk
# City not found.  Skipping...
# processing record 1 of set 5 | chapulhuacan
# processing record 2 of set 5 | kapaa
# processing record 3 of set 5 | isangel
# processing record 4 of set 5 | havoysund
# processing record 5 of set 5 | edd
# processing record 6 of set 5 | sitka
# processing record 7 of set 5 | ahome
# processing record 8 of set 5 | port hedland
# processing record 9 of set 5 | kautokeino
# processing record 10 of set 5 | airai
# processing record 11 of set 5 | esperance
# processing record 12 of set 5 | vardo
# processing record 13 of set 5 | mahebourg
# processing record 14 of set 5 | cumaribo
# City not found.  Skipping...
# processing record 14 of set 5 | sault sainte marie
# processing record 15 of set 5 | vila velha
# processing record 16 of set 5 | kavieng
# processing record 17 of set 5 | kahului
# processing record 18 of set 5 | atasu
# processing record 19 of set 5 | saravan
# processing record 20 of set 5 | kloulklubed
# processing record 21 of set 5 | igrim
# processing record 22 of set 5 | grindavik
# processing record 23 of set 5 | oistins
# processing record 24 of set 5 | bredasdorp
# processing record 25 of set 5 | haines junction
# processing record 26 of set 5 | tessalit
# processing record 27 of set 5 | sakaiminato
# processing record 28 of set 5 | karaton
# processing record 29 of set 5 | temaraia
# City not found.  Skipping...
# processing record 29 of set 5 | merrill
# processing record 30 of set 5 | geraldton
# processing record 31 of set 5 | norman wells
# processing record 32 of set 5 | martinsville
# processing record 33 of set 5 | linhares
# processing record 34 of set 5 | hay river
# processing record 35 of set 5 | buin
# processing record 36 of set 5 | sainte-marie
# processing record 37 of set 5 | swan river
# processing record 38 of set 5 | beira
# processing record 39 of set 5 | pingyin
# processing record 40 of set 5 | coahuayana
# processing record 41 of set 5 | lac du bonnet
# processing record 42 of set 5 | byron bay
# processing record 43 of set 5 | saint anthony
# processing record 44 of set 5 | nalut
# processing record 45 of set 5 | bundaberg
# processing record 46 of set 5 | nakusp
# processing record 47 of set 5 | sahiwal
# processing record 48 of set 5 | constitucion
# processing record 49 of set 5 | jumla
# processing record 50 of set 5 | altos
# processing record 0 of set 6 | shuyskoye
# processing record 1 of set 6 | salina
# processing record 2 of set 6 | puerto colombia
# processing record 3 of set 6 | baft
# processing record 4 of set 6 | naze
# processing record 5 of set 6 | langsa
# processing record 6 of set 6 | oyama
# processing record 7 of set 6 | mount gambier
# processing record 8 of set 6 | barentsburg
# City not found.  Skipping...
# processing record 8 of set 6 | sloboda
# processing record 9 of set 6 | olafsvik
# City not found.  Skipping...
# processing record 9 of set 6 | cruz grande
# processing record 10 of set 6 | auki
# processing record 11 of set 6 | avera
# processing record 12 of set 6 | bethel
# processing record 13 of set 6 | ape
# processing record 14 of set 6 | sao joao da barra
# processing record 15 of set 6 | oneonta
# processing record 16 of set 6 | ierapetra
# processing record 17 of set 6 | forio
# processing record 18 of set 6 | dzhusaly
# City not found.  Skipping...
# processing record 18 of set 6 | koulikoro
# processing record 19 of set 6 | sandy bay
# processing record 20 of set 6 | mount isa
# processing record 21 of set 6 | adre
# processing record 22 of set 6 | yuancheng
# City not found.  Skipping...
# processing record 22 of set 6 | trzebiatow
# processing record 23 of set 6 | keetmanshoop
# processing record 24 of set 6 | mao
# processing record 25 of set 6 | kismayo
# City not found.  Skipping...
# processing record 25 of set 6 | gizo
# processing record 26 of set 6 | dauphin
# processing record 27 of set 6 | ribeira grande
# processing record 28 of set 6 | guerrero negro
# processing record 29 of set 6 | mae hong son
# processing record 30 of set 6 | edson
# processing record 31 of set 6 | conde
# processing record 32 of set 6 | ormara
# processing record 33 of set 6 | marcona
# City not found.  Skipping...
# processing record 33 of set 6 | wattegama
# processing record 34 of set 6 | mountain home
# processing record 35 of set 6 | sorvag
# City not found.  Skipping...
# processing record 35 of set 6 | volterra
# processing record 36 of set 6 | ugoofaaru
# processing record 37 of set 6 | mys shmidta
# City not found.  Skipping...
# processing record 37 of set 6 | vestmannaeyjar
# processing record 38 of set 6 | ormos korthiou
# City not found.  Skipping...
# processing record 38 of set 6 | igarka
# processing record 39 of set 6 | sangmelima
# processing record 40 of set 6 | jackson
# processing record 41 of set 6 | honningsvag
# processing record 42 of set 6 | kirakira
# processing record 43 of set 6 | gubkinskiy
# processing record 44 of set 6 | libourne
# processing record 45 of set 6 | slave lake
# processing record 46 of set 6 | knysna
# processing record 47 of set 6 | salym
# processing record 48 of set 6 | huarmey
# processing record 49 of set 6 | kinkala
# processing record 50 of set 6 | santa rosa del sur
# processing record 0 of set 7 | berdigestyakh
# processing record 1 of set 7 | tazovskiy
# processing record 2 of set 7 | kars
# processing record 3 of set 7 | marzuq
# processing record 4 of set 7 | virginia beach
# processing record 5 of set 7 | rodrigues alves
# processing record 6 of set 7 | tateyama
# processing record 7 of set 7 | phetchabun
# processing record 8 of set 7 | gerash
# processing record 9 of set 7 | quartucciu
# processing record 10 of set 7 | mantua
# processing record 11 of set 7 | dolbeau
# City not found.  Skipping...
# processing record 11 of set 7 | weligama
# processing record 12 of set 7 | quatre cocos
# processing record 13 of set 7 | juneau
# processing record 14 of set 7 | cervo
# processing record 15 of set 7 | mahibadhoo
# processing record 16 of set 7 | svetlogorsk
# processing record 17 of set 7 | goderich
# processing record 18 of set 7 | balabac
# processing record 19 of set 7 | garbolovo
# processing record 20 of set 7 | burica
# City not found.  Skipping...
# processing record 20 of set 7 | pauini
# processing record 21 of set 7 | charlestown
# processing record 22 of set 7 | anadyr
# processing record 23 of set 7 | lethbridge
# processing record 24 of set 7 | chapais
# processing record 25 of set 7 | rwamagana
# processing record 26 of set 7 | kabalo
# processing record 27 of set 7 | upernavik
# processing record 28 of set 7 | baghdad
# processing record 29 of set 7 | faya
# processing record 30 of set 7 | brotas
# processing record 31 of set 7 | fairhope
# processing record 32 of set 7 | mangan
# processing record 33 of set 7 | bay roberts
# processing record 34 of set 7 | sunndalsora
# processing record 35 of set 7 | vanimo
# processing record 36 of set 7 | floresta
# processing record 37 of set 7 | amderma
# City not found.  Skipping...
# processing record 37 of set 7 | pacifica
# processing record 38 of set 7 | narsaq
# processing record 39 of set 7 | qixia
# processing record 40 of set 7 | mbandaka
# processing record 41 of set 7 | saleaula
# City not found.  Skipping...
# processing record 41 of set 7 | ust-barguzin
# processing record 42 of set 7 | angoche
# processing record 43 of set 7 | varkaus
# processing record 44 of set 7 | dodge city
# processing record 45 of set 7 | ahuimanu
# processing record 46 of set 7 | nador
# processing record 47 of set 7 | belmonte
# processing record 48 of set 7 | millau
# processing record 49 of set 7 | razdolnoye
# processing record 50 of set 7 | touros
# processing record 0 of set 8 | jingdezhen
# processing record 1 of set 8 | flin flon
# processing record 2 of set 8 | buraydah
# processing record 3 of set 8 | araouane
# processing record 4 of set 8 | henties bay
# processing record 5 of set 8 | veliko gradiste
# processing record 6 of set 8 | polis
# processing record 7 of set 8 | papara
# processing record 8 of set 8 | padang
# processing record 9 of set 8 | santa isabel do rio negro
# processing record 10 of set 8 | rameswaram
# processing record 11 of set 8 | beyneu
# processing record 12 of set 8 | poum
# processing record 13 of set 8 | vegueta
# processing record 14 of set 8 | louisbourg
# City not found.  Skipping...
# processing record 14 of set 8 | beloha
# processing record 15 of set 8 | aklavik
# processing record 16 of set 8 | saint-ambroise
# processing record 17 of set 8 | whitehorse
# processing record 18 of set 8 | port macquarie
# processing record 19 of set 8 | kutum
# processing record 20 of set 8 | vao
# processing record 21 of set 8 | kuito
# processing record 22 of set 8 | mayo
# processing record 23 of set 8 | russkiy aktash
# processing record 24 of set 8 | yeppoon
# processing record 25 of set 8 | meyungs
# City not found.  Skipping...
# processing record 25 of set 8 | gap
# processing record 26 of set 8 | richards bay
# processing record 27 of set 8 | hue
# processing record 28 of set 8 | porto novo
# processing record 29 of set 8 | giehun
# processing record 30 of set 8 | lianran
# processing record 31 of set 8 | portree
# processing record 32 of set 8 | berck
# processing record 33 of set 8 | ponta delgada
# processing record 34 of set 8 | atuntaqui
# processing record 35 of set 8 | ledyard
# processing record 36 of set 8 | witu
# processing record 37 of set 8 | mandalgovi
# processing record 38 of set 8 | nuristan
# processing record 39 of set 8 | viradouro
# processing record 40 of set 8 | sundumbili
# processing record 41 of set 8 | yingkou
# processing record 42 of set 8 | berbera
# City not found.  Skipping...
# processing record 42 of set 8 | hovd
# processing record 43 of set 8 | harnosand
# processing record 44 of set 8 | warqla
# City not found.  Skipping...
# processing record 44 of set 8 | aviemore
# processing record 45 of set 8 | lompoc
# processing record 46 of set 8 | losevo
# processing record 47 of set 8 | puerto del rosario
# processing record 48 of set 8 | vila
# processing record 49 of set 8 | hasaki
# processing record 50 of set 8 | matagami
# processing record 0 of set 9 | samarai
# processing record 1 of set 9 | nishihara
# processing record 2 of set 9 | fereydunshahr
# processing record 3 of set 9 | visnes
# processing record 4 of set 9 | gorgan
# processing record 5 of set 9 | kiama
# processing record 6 of set 9 | margate
# processing record 7 of set 9 | beringovskiy
# processing record 8 of set 9 | evensk
# processing record 9 of set 9 | guanare
# processing record 10 of set 9 | adrar
# processing record 11 of set 9 | kurilsk
# processing record 12 of set 9 | acapulco
# processing record 13 of set 9 | agirish
# processing record 14 of set 9 | nola
# processing record 15 of set 9 | fairbanks
# processing record 16 of set 9 | eirunepe
# processing record 17 of set 9 | teknaf
# processing record 18 of set 9 | verkhnyachka
# processing record 19 of set 9 | cabatuan
# processing record 20 of set 9 | kisangani
# processing record 21 of set 9 | lasa
# processing record 22 of set 9 | bababe
# City not found.  Skipping...
# processing record 22 of set 9 | cagayan de tawi-tawi
# City not found.  Skipping...
# processing record 22 of set 9 | nanortalik
# processing record 23 of set 9 | kaoma
# processing record 24 of set 9 | vaitupu
# City not found.  Skipping...
# processing record 24 of set 9 | sabaudia
# processing record 25 of set 9 | banjar
# processing record 26 of set 9 | kharitonovo
# processing record 27 of set 9 | komsomolskiy
# processing record 28 of set 9 | salinas
# processing record 29 of set 9 | lamar
# processing record 30 of set 9 | tubruq
# City not found.  Skipping...
# processing record 30 of set 9 | namtsy
# processing record 31 of set 9 | blagoyevo
# processing record 32 of set 9 | ajdabiya
# processing record 33 of set 9 | la presa
# processing record 34 of set 9 | grand river south east
# City not found.  Skipping...
# processing record 34 of set 9 | karimganj
# processing record 35 of set 9 | san lawrenz
# processing record 36 of set 9 | kamenka
# processing record 37 of set 9 | tumannyy
# City not found.  Skipping...
# processing record 37 of set 9 | dzerzhinsk
# processing record 38 of set 9 | taunggyi
# processing record 39 of set 9 | ilulissat
# processing record 40 of set 9 | bam
# processing record 41 of set 9 | abalak
# processing record 42 of set 9 | brae
# processing record 43 of set 9 | ust-tsilma
# processing record 44 of set 9 | dryden
# processing record 45 of set 9 | sanary-sur-mer
# processing record 46 of set 9 | atar
# processing record 47 of set 9 | porto seguro
# processing record 48 of set 9 | alice town
# processing record 49 of set 9 | bahia honda
# processing record 50 of set 9 | iquitos
# processing record 0 of set 10 | kudahuvadhoo
# processing record 1 of set 10 | bolonchen
# City not found.  Skipping...
# processing record 1 of set 10 | ahipara
# processing record 2 of set 10 | santa rosa
# processing record 3 of set 10 | boguchany
# processing record 4 of set 10 | surt
# processing record 5 of set 10 | chandbali
# processing record 6 of set 10 | ternate
# processing record 7 of set 10 | vila franca do campo
# processing record 8 of set 10 | pyapon
# processing record 9 of set 10 | ferkessedougou
# processing record 10 of set 10 | calabozo
# processing record 11 of set 10 | san cristobal
# processing record 12 of set 10 | bengkulu
# City not found.  Skipping...
# processing record 12 of set 10 | waipawa
# processing record 13 of set 10 | volksrust
# processing record 14 of set 10 | makakilo city
# processing record 15 of set 10 | sulina
# City not found.  Skipping...
# processing record 15 of set 10 | okahandja
# processing record 16 of set 10 | utiroa
# City not found.  Skipping...
# processing record 16 of set 10 | darhan
# processing record 17 of set 10 | keti bandar
# processing record 18 of set 10 | chagda
# City not found.  Skipping...
# processing record 18 of set 10 | north platte
# processing record 19 of set 10 | misratah
# processing record 20 of set 10 | hambantota
# processing record 21 of set 10 | mehran
# processing record 22 of set 10 | campobello di mazara
# processing record 23 of set 10 | coos bay
# processing record 24 of set 10 | ornskoldsvik
# processing record 25 of set 10 | amiens
# processing record 26 of set 10 | gilgit
# processing record 27 of set 10 | umm kaddadah
# processing record 28 of set 10 | penzance
# processing record 29 of set 10 | zaraza
# processing record 30 of set 10 | cayenne
# processing record 31 of set 10 | sorong
# processing record 32 of set 10 | pincher creek
# processing record 33 of set 10 | taoudenni
# processing record 34 of set 10 | crotone
# processing record 35 of set 10 | manggar
# processing record 36 of set 10 | hohhot
# processing record 37 of set 10 | leningradskiy
# processing record 38 of set 10 | kaiwaka
# processing record 39 of set 10 | tabiauea
# City not found.  Skipping...
# processing record 39 of set 10 | salalah
# processing record 40 of set 10 | sinnamary
# processing record 41 of set 10 | khasan
# processing record 42 of set 10 | painesville
# processing record 43 of set 10 | manosque
# processing record 44 of set 10 | nizhnevartovsk
# processing record 45 of set 10 | nizhneyansk
# City not found.  Skipping...
# processing record 45 of set 10 | jatai
# processing record 46 of set 10 | luwuk
# processing record 47 of set 10 | turka
# processing record 48 of set 10 | gayny
# processing record 49 of set 10 | comodoro rivadavia
# processing record 50 of set 10 | nantucket
# processing record 0 of set 11 | fort nelson
# processing record 1 of set 11 | nome
# processing record 2 of set 11 | bagotville
# processing record 3 of set 11 | dunedin
# processing record 4 of set 11 | carutapera
# processing record 5 of set 11 | nabire
# processing record 6 of set 11 | doha
# processing record 7 of set 11 | andenes
# City not found.  Skipping...
# processing record 7 of set 11 | imeni babushkina
# processing record 8 of set 11 | barinas
# processing record 9 of set 11 | khakhea
# processing record 10 of set 11 | fevralsk
# City not found.  Skipping...
# processing record 10 of set 11 | portland
# processing record 11 of set 11 | burnie
# processing record 12 of set 11 | koslan
# processing record 13 of set 11 | harper
# processing record 14 of set 11 | sarlat-la-caneda
# processing record 15 of set 11 | hofn
# processing record 16 of set 11 | peremyshlyany
# processing record 17 of set 11 | mahon
# processing record 18 of set 11 | suhbaatar
# processing record 19 of set 11 | shingu
# processing record 20 of set 11 | ramhormoz
# processing record 21 of set 11 | constantine
# processing record 22 of set 11 | college
# processing record 23 of set 11 | alice springs
# processing record 24 of set 11 | dwarka
# processing record 25 of set 11 | duku
# processing record 26 of set 11 | puro
# processing record 27 of set 11 | takoradi
# processing record 28 of set 11 | bur gabo
# City not found.  Skipping...
# processing record 28 of set 11 | amparafaravola
# processing record 29 of set 11 | werda
# processing record 30 of set 11 | kaeo
# processing record 31 of set 11 | okhotsk
# processing record 32 of set 11 | eydhafushi
# processing record 33 of set 11 | camacupa
# processing record 34 of set 11 | kunyang
# processing record 35 of set 11 | ukiah
# processing record 36 of set 11 | nicoya
# processing record 37 of set 11 | tuxpan
# processing record 38 of set 11 | thinadhoo
# processing record 39 of set 11 | mangrol
# processing record 40 of set 11 | cochrane
# ------------------------------------
# Data Retrieval Complete
# ------------------------------------

# %%
citydata_df
# Out:
#                  City Cloudiness Country        Date Humidity    Lat     Lng  \
# 0        sentyabrskiy
# 1            chabahar          0      IR  1575338440       58  25.29   60.65
# 2           dien bien
# 3         yellowknife         90      CA  1575338344       85  62.45 -114.38
# 4       mar del plata        100      AR  1575338440       56 -46.43  -67.52
# 5               olpad         55      IN  1575338440       73  21.34   72.75
# 6              atuona         87      PF  1575338440       63   -9.8 -139.03
# 7           cape town         75      ZA  1575338416       62 -33.93   18.42
# 8               xinyu          0      CN  1575338440       36   27.8  114.93
# 9            nenjiang        100      CN  1575338440       81  49.17  125.23
# 10       puerto ayora         18      EC  1575338440       93  -0.74  -90.35
# 11           katsuura         40      JP  1575338440       59  33.93   134.5
# 12            wanning         75      AT  1575338440       80  48.64   13.53
# 13      cockburn town          0      TC  1575338440       67  21.46  -71.14
# 14             bonthe          0      SL  1575338440       82   7.53   -12.5
# 15               lebu         33      ET  1575338440       91   8.96   38.73
# 16             albany         90      US  1575338434       68  42.65  -73.75
# 17            agliana         40      IT  1575338440       71   43.9      11
# 18            mataura         82      NZ  1575338440       49 -46.19  168.86
# 19            rikitea         91      PF  1575338440       84 -23.12 -134.97
# 20             avarua        100      CK  1575338441       78 -21.21 -159.78
# 21            ushuaia         75      AR  1575338441       76 -54.81  -68.31
# 22        grand gaube         40      MU  1575338441       73 -20.01   57.66
# 23          jamestown          2      AU  1575338292       39 -33.21   138.6
# 24          taolanaro
# 25                osa         70      RU  1575338441       95  57.28   55.46
# 26             hobart         75      AU  1575338201       38 -42.88  147.33
# 27             bassar         72      TG  1575338441       31   9.26    0.78
# 28           necochea         67      AR  1575338441       56 -38.55  -58.74
# 29           thompson         90      CA  1575338441       92  55.74  -97.86
# ..                ...        ...     ...         ...      ...    ...     ...
# 571            koslan        100      RU  1575338489       92  63.46    48.9
# 572            harper          1      US  1575338489       45   30.3  -99.24
# 573  sarlat-la-caneda          0      FR  1575338490       92  44.89    1.22
# 574              hofn        100      IS  1575338490       92  64.25  -15.21
# 575     peremyshlyany         90      UA  1575338490       92  49.67   24.56
# 576             mahon         75      IE  1575338490       93  51.89    -8.4
# 577         suhbaatar         68      MN  1575338490       81  50.23  106.21
# 578            shingu         40      JP  1575338490       46  33.72  135.99
# 579         ramhormoz         97      IR  1575338490       69  31.28    49.6
# 580       constantine         20      DZ  1575338490      100  36.36    6.61
# 581           college         90      US  1575338490       85  64.86  -147.8
# 582     alice springs          0      AU  1575338490       25  -23.7  133.88
# 583            dwarka          0      IN  1575338490       81  28.58   77.04
# 584              duku        100      ID  1575338490       96  -1.19  100.47
# 585              puro        100      PH  1575338490       85  13.13  123.76
# 586          takoradi        100      GH  1575338491       84   4.89   -1.75
# 587          bur gabo
# 588    amparafaravola         73      MG  1575338491       86 -17.68   48.22
# 589             werda        100      BW  1575338491       28 -25.27   23.28
# 590              kaeo         83      NZ  1575338491      100  -35.1  173.78
# 591           okhotsk        100      RU  1575338491       68  59.36  143.24
# 592        eydhafushi         98      MV  1575338491       79    5.1   73.07
# 593          camacupa        100      AO  1575338491       98 -12.02   17.48
# 594           kunyang          0      CN  1575338491       23  27.66  120.56
# 595             ukiah         90      US  1575338491       71  39.15 -123.21
# 596            nicoya         20      CR  1575338403       65  10.15  -85.45
# 597            tuxpan         75      MX  1575338492       88  19.56 -103.38
# 598         thinadhoo         35      MV  1575338492       77   0.53   72.93
# 599           mangrol          0      IN  1575338492       43  25.33   76.51
# 600          cochrane         42      CL  1575338412       96 -47.25  -72.57
#
#     Max Temp Wind Speed
# 0
# 1      68.41       7.09
# 2
# 3       10.4      12.75
# 4      58.39      24.52
# 5       75.2       9.17
# 6      80.67        8.3
# 7      60.01      16.11
# 8      52.75       6.38
# 9      -7.31       11.3
# 10        70          3
# 11        54      17.22
# 12      33.8       3.36
# 13     80.46       5.97
# 14     79.39       4.54
# 15     49.71        2.1
# 16     28.99      11.41
# 17      53.6       3.36
# 18     66.38      17.07
# 19     75.56      13.49
# 20      78.8       5.82
# 21        50      24.16
# 22      75.2       5.82
# 23     69.01      16.28
# 24
# 25     11.32       7.43
# 26        59      33.33
# 27      76.1       2.95
# 28     69.01       8.99
# 29      12.2        4.7
# ..       ...        ...
# 571    18.52       9.24
# 572       52       8.05
# 573    33.01       3.36
# 574    49.57       35.9
# 575       32      13.42
# 576     37.4       5.82
# 577      9.7       3.36
# 578     53.6      18.34
# 579    61.11          7
# 580     42.8       2.24
# 581       14        4.7
# 582     84.2      12.75
# 583       50       3.36
# 584    71.83       1.34
# 585    79.57      11.81
# 586    79.57       7.61
# 587
# 588    63.61       8.61
# 589    82.17       9.53
# 590       70      26.19
# 591    -0.74      16.89
# 592    82.58      10.65
# 593    63.25       2.89
# 594       64       5.57
# 595    57.99      10.29
# 596     80.6       9.17
# 597     75.2       2.06
# 598    83.32      13.78
# 599    62.22       3.29
# 600    35.85        5.1
#
# [601 rows x 9 columns]

# %%
citydata_df.count()

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Export file into a csv 
citydata_df.to_csv("cities.csv", index=False)

# %%
citydata_df.dtypes

# %%
# Convert data into numerical float type for graphing
citydata_df["Cloudiness"] = pd.to_numeric(citydata_df["Cloudiness"])
citydata_df["Date"] = pd.to_numeric(citydata_df["Date"])
citydata_df["Humidity"] = pd.to_numeric(citydata_df["Humidity"])
citydata_df["Lat"] = pd.to_numeric(citydata_df["Lat"])
citydata_df["Lng"] = pd.to_numeric(citydata_df["Lng"])
citydata_df["Max Temp"] = pd.to_numeric(citydata_df["Max Temp"])
citydata_df["Wind Speed"] = pd.to_numeric(citydata_df["Wind Speed"])

# %%
citydata_df.dtypes

# %% [markdown]
# Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Set x-axis and y-axis for graph
x_axis = citydata_df["Lat"]
y_axis = citydata_df["Max Temp"]

# Scatter Plot
plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black", alpha=1.0)

# Labels for graph
plt.title("City Latitude vs. Max Temperature (12/01/19)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("latitude_temp.png")

plt.show

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
x_axis = citydata_df["Lat"]
y_axis = citydata_df["Humidity"]

plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black", alpha=1.0)

plt.title("City Latitude vs. Humidity (12/01/19)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("latitude_humidity.png")

plt.show

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
x_axis = citydata_df["Lat"]
y_axis = citydata_df["Cloudiness"]

plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black", alpha=1.0)

plt.title("City Latitude vs. Cloudiness (12/01/19)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("latitude_cloudiness.png")

plt.show

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
x_axis = citydata_df["Lat"]
y_axis = citydata_df["Wind Speed"]

plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black", alpha=1.0)

plt.title("City Latitude vs. Wind Speed (12/01/19)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("latitude_windspeed.png")

plt.show
